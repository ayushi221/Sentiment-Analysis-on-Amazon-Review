# %% [markdown]
# ## imports module and read data

# %%
import pandas as pd
import numpy as np
import warnings
df = pd.read_csv("amazon.csv")
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (1,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                          id  \
# 0      AVqkIhwDv8e3D1O-lebb
# 1      AVqkIhwDv8e3D1O-lebb
# 2      AVqkIhwDv8e3D1O-lebb
# 3      AVqkIhwDv8e3D1O-lebb
# 4      AVqkIhwDv8e3D1O-lebb
# ...                     ...
# 34655  AVpfiBlyLJeJML43-4Tp
# 34656  AVpfiBlyLJeJML43-4Tp
# 34657  AVpfiBlyLJeJML43-4Tp
# 34658  AVpfiBlyLJeJML43-4Tp
# 34659  AVpfiBlyLJeJML43-4Tp
#
#                                                     name       asins   brand  \
# 0      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  B01AHB9CN2  Amazon
# 1      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  B01AHB9CN2  Amazon
# 2      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  B01AHB9CN2  Amazon
# 3      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  B01AHB9CN2  Amazon
# 4      All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...  B01AHB9CN2  Amazon
# ...                                                  ...         ...     ...
# 34655                                                NaN  B006GWO5WK  Amazon
# 34656                                                NaN  B006GWO5WK  Amazon
# 34657                                                NaN  B006GWO5WK  Amazon
# 34658                                                NaN  B006GWO5WK  Amazon
# 34659                                                NaN  B006GWO5WK  Amazon
#
#                                               categories  \
# 0      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4      Electronics,iPad & Tablets,All Tablets,Fire Ta...
# ...                                                  ...
# 34655  Computers/Tablets & Networking,Tablet & eBook ...
# 34656  Computers/Tablets & Networking,Tablet & eBook ...
# 34657  Computers/Tablets & Networking,Tablet & eBook ...
# 34658  Computers/Tablets & Networking,Tablet & eBook ...
# 34659  Computers/Tablets & Networking,Tablet & eBook ...
#
#                                                     keys  \
# 0      841667104676,amazon/53004484,amazon/b01ahb9cn2...
# 1      841667104676,amazon/53004484,amazon/b01ahb9cn2...
# 2      841667104676,amazon/53004484,amazon/b01ahb9cn2...
# 3      841667104676,amazon/53004484,amazon/b01ahb9cn2...
# 4      841667104676,amazon/53004484,amazon/b01ahb9cn2...
# ...                                                  ...
# 34655  newamazonkindlefirehd9wpowerfastadaptercharger...
# 34656  newamazonkindlefirehd9wpowerfastadaptercharger...
# 34657  newamazonkindlefirehd9wpowerfastadaptercharger...
# 34658  newamazonkindlefirehd9wpowerfastadaptercharger...
# 34659  newamazonkindlefirehd9wpowerfastadaptercharger...
#
#                        manufacturer              reviews.date  \
# 0                            Amazon  2017-01-13T00:00:00.000Z
# 1                            Amazon  2017-01-13T00:00:00.000Z
# 2                            Amazon  2017-01-13T00:00:00.000Z
# 3                            Amazon  2017-01-13T00:00:00.000Z
# 4                            Amazon  2017-01-12T00:00:00.000Z
# ...                             ...                       ...
# 34655  Amazon Digital Services, Inc      2012-09-18T00:00:00Z
# 34656  Amazon Digital Services, Inc      2012-11-21T00:00:00Z
# 34657  Amazon Digital Services, Inc      2012-10-19T00:00:00Z
# 34658  Amazon Digital Services, Inc      2012-10-31T00:00:00Z
# 34659  Amazon Digital Services, Inc      2012-12-23T00:00:00Z
#
#           reviews.dateAdded  \
# 0      2017-07-03T23:33:15Z
# 1      2017-07-03T23:33:15Z
# 2      2017-07-03T23:33:15Z
# 3      2017-07-03T23:33:15Z
# 4      2017-07-03T23:33:15Z
# ...                     ...
# 34655                   NaN
# 34656                   NaN
# 34657                   NaN
# 34658                   NaN
# 34659                   NaN
#
#                                         reviews.dateSeen  ...  \
# 0      2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...
# 1      2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...
# 2      2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...
# 3      2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...
# 4      2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...
# ...                                                  ...  ...
# 34655                               2015-08-29T00:00:00Z  ...
# 34656                               2015-09-02T00:00:00Z  ...
# 34657                               2015-09-04T00:00:00Z  ...
# 34658                               2015-09-01T00:00:00Z  ...
# 34659                               2015-11-01T00:00:00Z  ...
#
#       reviews.doRecommend reviews.id  reviews.numHelpful  reviews.rating  \
# 0                    True        NaN                 0.0             5.0
# 1                    True        NaN                 0.0             5.0
# 2                    True        NaN                 0.0             5.0
# 3                    True        NaN                 0.0             4.0
# 4                    True        NaN                 0.0             5.0
# ...                   ...        ...                 ...             ...
# 34655                 NaN        NaN                 NaN             3.0
# 34656                 NaN        NaN                 NaN             1.0
# 34657                 NaN        NaN                 NaN             1.0
# 34658                 NaN        NaN                 NaN             1.0
# 34659                 NaN        NaN                 NaN             1.0
#
#                                       reviews.sourceURLs  \
# 0      http://reviews.bestbuy.com/3545/5620406/review...
# 1      http://reviews.bestbuy.com/3545/5620406/review...
# 2      http://reviews.bestbuy.com/3545/5620406/review...
# 3      http://reviews.bestbuy.com/3545/5620406/review...
# 4      http://reviews.bestbuy.com/3545/5620406/review...
# ...                                                  ...
# 34655  http://www.amazon.com/Amazon-PowerFast-Adapter...
# 34656  http://www.amazon.com/Amazon-PowerFast-Adapter...
# 34657  http://www.amazon.com/Amazon-PowerFast-Adapter...
# 34658  http://www.amazon.com/Amazon-PowerFast-Adapter...
# 34659  http://www.amazon.com/Amazon-PowerFast-Adapter...
#
#                                             reviews.text  \
# 0      This product so far has not disappointed. My c...
# 1      great for beginner or experienced person. Boug...
# 2      Inexpensive tablet for him to use and learn on...
# 3      I've had my Fire HD 8 two weeks now and I love...
# 4      I bought this for my grand daughter when she c...
# ...                                                  ...
# 34655  This is not appreciably faster than any other ...
# 34656  Amazon should include this charger with the Ki...
# 34657  Love my Kindle Fire but I am really disappoint...
# 34658  I was surprised to find it did not come with a...
# 34659  to spite the fact that i have nothing but good...
#
#                                            reviews.title reviews.userCity  \
# 0                                                 Kindle              NaN
# 1                                              very fast              NaN
# 2                Beginner tablet for our 9 year old son.              NaN
# 3                                                Good!!!              NaN
# 4                              Fantastic Tablet for kids              NaN
# ...                                                  ...              ...
# 34655  Not appreciably faster than any other 1.8A cha...              NaN
# 34656                                 Should be included              NaN
# 34657                              Disappointing Charger              NaN
# 34658                                Not worth the money              NaN
# 34659                              as with everyone else              NaN
#
#        reviews.userProvince  reviews.username
# 0                       NaN           Adapter
# 1                       NaN            truman
# 2                       NaN             DaveZ
# 3                       NaN            Shacks
# 4                       NaN         explore42
# ...                     ...               ...
# 34655                   NaN              Kris
# 34656                   NaN  Jonathan Stewart
# 34657                   NaN          J Lawson
# 34658                   NaN    Just the Buyer
# 34659                   NaN             sandi
#
# [34660 rows x 21 columns]

# %% [markdown]
# ## Quick Look at the Raw Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore",category=DeprecationWarning)
warnings.filterwarnings("ignore",category=UserWarning)
sns.set_style("whitegrid") # Plotting style
np.random.seed(7) # seeding random number generator
df = pd.read_csv("amazon.csv")
print(df.head())
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 3  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 4  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#                reviews.date     reviews.dateAdded  \
# 0  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 1  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 2  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 3  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 4  2017-01-12T00:00:00.000Z  2017-07-03T23:33:15Z
#
#                                     reviews.dateSeen  ... reviews.doRecommend  \
# 0  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 1  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 2  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 3  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
# 4  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                True
#
#   reviews.id  reviews.numHelpful  reviews.rating  \
# 0        NaN                 0.0             5.0
# 1        NaN                 0.0             5.0
# 2        NaN                 0.0             5.0
# 3        NaN                 0.0             4.0
# 4        NaN                 0.0             5.0
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5620406/review...
# 1  http://reviews.bestbuy.com/3545/5620406/review...
# 2  http://reviews.bestbuy.com/3545/5620406/review...
# 3  http://reviews.bestbuy.com/3545/5620406/review...
# 4  http://reviews.bestbuy.com/3545/5620406/review...
#
#                                         reviews.text  \
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...
#
#                              reviews.title reviews.userCity  \
# 0                                   Kindle              NaN
# 1                                very fast              NaN
# 2  Beginner tablet for our 9 year old son.              NaN
# 3                                  Good!!!              NaN
# 4                Fantastic Tablet for kids              NaN
#
#    reviews.userProvince  reviews.username
# 0                   NaN           Adapter
# 1                   NaN            truman
# 2                   NaN             DaveZ
# 3                   NaN            Shacks
# 4                   NaN         explore42
#
# [5 rows x 21 columns]

# %%
#Describing the Dataset
data = df.copy()
data.describe()
# Out:
#        reviews.didPurchase  reviews.id  reviews.numHelpful  reviews.rating  \
# count                  0.0         0.0        15614.000000    16016.000000
# mean                   NaN         NaN            0.489945        4.486076
# std                    NaN         NaN            7.882194        0.793940
# min                    NaN         NaN            0.000000        1.000000
# 25%                    NaN         NaN            0.000000        4.000000
# 50%                    NaN         NaN            0.000000        5.000000
# 75%                    NaN         NaN            0.000000        5.000000
# max                    NaN         NaN          730.000000        5.000000
#
#        reviews.userCity  reviews.userProvince
# count               0.0                   0.0
# mean                NaN                   NaN
# std                 NaN                   NaN
# min                 NaN                   NaN
# 25%                 NaN                   NaN
# 50%                 NaN                   NaN
# 75%                 NaN                   NaN
# max                 NaN                   NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16044 entries, 0 to 16043
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    16044 non-null  object
#  1   name                  16044 non-null  object
#  2   asins                 16042 non-null  object
#  3   brand                 16044 non-null  object
#  4   categories            16044 non-null  object
#  5   keys                  16044 non-null  object
#  6   manufacturer          16044 non-null  object
#  7   reviews.date          16031 non-null  object
#  8   reviews.dateAdded     14352 non-null  object
#  9   reviews.dateSeen      16044 non-null  object
#  10  reviews.didPurchase   0 non-null      float64
#  11  reviews.doRecommend   15600 non-null  object
#  12  reviews.id            0 non-null      float64
#  13  reviews.numHelpful    15614 non-null  float64
#  14  reviews.rating        16016 non-null  float64
#  15  reviews.sourceURLs    16044 non-null  object
#  16  reviews.text          16043 non-null  object
#  17  reviews.title         16042 non-null  object
#  18  reviews.userCity      0 non-null      float64
#  19  reviews.userProvince  0 non-null      float64
#  20  reviews.username      16042 non-null  object
# dtypes: float64(6), object(15)
# memory usage: 2.6+ MB

# %% [markdown]
# ## Visualizing the distributions of numerical variables:

# %%
# Visualizing the distributions of numerical variables using histogram:
data.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ## Split into Train/Test

# %%
from sklearn.model_selection import StratifiedShuffleSplit
print("Before {}".format(len(data)))
dataAfter = data.dropna(subset=["reviews.rating"])
# Removes all NAN in reviews.rating
print("After {}".format(len(dataAfter)))
dataAfter["reviews.rating"] = dataAfter["reviews.rating"].astype(int)
# Out:
# Before 16044
# After 16016

# %%
split = StratifiedShuffleSplit(n_splits=5, test_size=0.2)
for train_index, test_index in split.split(dataAfter,
                                           dataAfter["reviews.rating"]): 
    strat_train = dataAfter.reindex(train_index)
    strat_test = dataAfter.reindex(test_index)

# %%
strat_train.shape,strat_test.shape
# Out:
# ((12812, 21), (3204, 21))

# %% [markdown]
# ## Check to see if train/test sets were stratified proportionately in comparison to raw data.

# %%
len(strat_train)
# Out:
# 12812

# %%
strat_train["reviews.rating"].value_counts()/len(strat_train)
# Out:
# 5.0    0.617156
# 4.0    0.297065
# 3.0    0.055027
# 1.0    0.014986
# 2.0    0.014049
# Name: reviews.rating, dtype: float64

# %%
len(strat_test)
# Out:
# 3204

# %%
strat_test["reviews.rating"].value_counts()/len(strat_test)
# Out:
# 5.0    0.607054
# 4.0    0.300250
# 3.0    0.059301
# 1.0    0.015918
# 2.0    0.015605
# Name: reviews.rating, dtype: float64

# %% [markdown]
# ## Data Exploration (Training Set)

# %%
reviews = strat_train.copy()
reviews.head(2)
# Out:
#                          id  \
# 11057  AVphgVaX1cnluZ0-DR74
# 5523   AVphgVaX1cnluZ0-DR74
#
#                                                     name       asins   brand  \
# 11057  Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes...  B018Y229OU  Amazon
# 5523   Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes...  B018Y229OU  Amazon
#
#                                               categories  \
# 11057  Fire Tablets,Tablets,Computers & Tablets,All T...
# 5523   Fire Tablets,Tablets,Computers & Tablets,All T...
#
#                                                     keys manufacturer  \
# 11057  firetablet7displaywifi8gbincludesspecialoffers...       Amazon
# 5523   firetablet7displaywifi8gbincludesspecialoffers...       Amazon
#
#                    reviews.date     reviews.dateAdded  \
# 11057  2016-01-16T00:00:00.000Z  2017-05-21T02:30:26Z
# 5523   2016-04-24T00:00:00.000Z  2017-04-03T19:25:36Z
#
#                                         reviews.dateSeen  ...  \
# 11057  2017-04-30T00:18:00.000Z,2017-06-07T08:13:00.000Z  ...
# 5523   2017-04-03T02:42:00.000Z,2017-04-30T00:07:00.0...  ...
#
#        reviews.doRecommend reviews.id  reviews.numHelpful  reviews.rating  \
# 11057                 True        NaN                 0.0             5.0
# 5523                  True        NaN                 0.0             5.0
#
#                                       reviews.sourceURLs  \
# 11057  http://reviews.bestbuy.com/3545/5025800/review...
# 5523   http://reviews.bestbuy.com/3545/5025800/review...
#
#                                             reviews.text  \
# 11057  A few years back I asked for and received a Ki...
# 5523   I purchased this Fire tablet for my wife becau...
#
#                         reviews.title reviews.userCity  reviews.userProvince  \
# 11057  Kindle Fire makes a great gift              NaN                   NaN
# 5523            A Nice Simple Tablet!              NaN                   NaN
#
#        reviews.username
# 11057              ddme
# 5523            Steve53
#
# [2 rows x 21 columns]

# %% [markdown]
# ## names / ASINs

# %%
len(reviews["name"].unique()), len(reviews["asins"].unique())
# Out:
# (21, 16)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12812 entries, 11057 to 13581
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    12790 non-null  object
#  1   name                  12790 non-null  object
#  2   asins                 12789 non-null  object
#  3   brand                 12790 non-null  object
#  4   categories            12790 non-null  object
#  5   keys                  12790 non-null  object
#  6   manufacturer          12790 non-null  object
#  7   reviews.date          12788 non-null  object
#  8   reviews.dateAdded     11512 non-null  object
#  9   reviews.dateSeen      12790 non-null  object
#  10  reviews.didPurchase   0 non-null      float64
#  11  reviews.doRecommend   12468 non-null  object
#  12  reviews.id            0 non-null      float64
#  13  reviews.numHelpful    12479 non-null  float64
#  14  reviews.rating        12790 non-null  float64
#  15  reviews.sourceURLs    12790 non-null  object
#  16  reviews.text          12789 non-null  object
#  17  reviews.title         12790 non-null  object
#  18  reviews.userCity      0 non-null      float64
#  19  reviews.userProvince  0 non-null      float64
#  20  reviews.username      12789 non-null  object
# dtypes: float64(6), object(15)
# memory usage: 2.2+ MB

# %%
reviews.groupby("asins")["name"].unique()
# Out:
# asins
# B005PB2T0S    [Amazon Kindle Lighted Leather Cover,,,\nKindl...
# B005PB2T2Q    [Fire Kids Edition Tablet, 7 Display, Wi-Fi, 1...
# B00DU15MU4    [Brand New Amazon Kindle Fire 16gb 7 Ips Displ...
# B00IOYAM4I    [Brand New Amazon Kindle Fire 16gb 7 Ips Displ...
# B00REQKWGA    [Brand New Amazon Kindle Fire 16gb 7 Ips Displ...
# B00VINDBJK    [Kindle Oasis E-reader with Leather Charging C...
# B00ZV9PXP2    [Fire Tablet, 7 Display, Wi-Fi, 8 GB - Include...
# B018T075DC    [Brand New Amazon Kindle Fire 16gb 7 Ips Displ...
# B018Y225IA    [Fire Kids Edition Tablet, 7 Display, Wi-Fi, 1...
# B018Y229OU    [Fire Tablet, 7 Display, Wi-Fi, 8 GB - Include...
# B018Y23MNM    [Fire Kids Edition Tablet, 7 Display, Wi-Fi, 1...
# B01AHB9C1E    [Fire HD 8 Tablet with Alexa, 8 HD Display, 32...
# B01AHB9CN2    [All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi...
# B01AHB9CYG    [All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi...
# B01J2G4VBG    [All-New Kindle E-reader - Black, 6 Glare-Free...
# Name: name, dtype: object

# %% [markdown]
# # # Lets see all the different names for this product that have 2 ASINs

# %%
# Lets see all the different names for this product that have 2 ASINs
different_names = reviews[reviews["asins"] == 
                          "B00L9EPT8O,B01E6AO69U"]["name"].unique()
for name in different_names:
    print(name)

# %%
reviews[reviews["asins"] == "B00L9EPT8O,B01E6AO69U"]["name"].value_counts()
# Out:
# Series([], Name: name, dtype: int64)

# %%
fig = plt.figure(figsize=(16,10))
ax1 = plt.subplot(211)
ax2 = plt.subplot(212, sharex = ax1)
reviews["asins"].value_counts().plot(kind="bar", ax=ax1, title="ASIN Frequency")
np.log10(reviews["asins"].value_counts()).plot(kind="bar", ax=ax2, 
                                               title="ASIN Frequency(Log10 Adjusted)") 
plt.show()

# %%
# Entire training dataset average rating
reviews["reviews.rating"].mean()
# Out:
# 4.489913995308835

# %%
asins_count_ix = reviews["asins"].value_counts().index
plt.subplots(2,1,figsize=(16,12))
plt.subplot(2,1,1)
reviews["asins"].value_counts().plot(kind="bar", title="ASIN Frequency")
plt.subplot(2,1,2)
sns.pointplot(x="asins", y="reviews.rating", order=asins_count_ix, data=reviews)
plt.xticks(rotation=90)
plt.show()

# %%
asins_count_ix = reviews["asins"].value_counts().index
plt.subplots(2,1,figsize=(16,12))
plt.subplot(2,1,1)
reviews["asins"].value_counts().plot(kind="bar", title="ASIN Frequency")
plt.show()
plt.subplots (2,1,figsize=(16,12))
sns.pointplot(x="asins", y="reviews.rating", order=asins_count_ix, data=reviews)
plt.xticks(rotation=90)
plt.subplots(2,1,figsize=(16,12))
plt.subplot(2,1,1)
reviews["asins"].value_counts().plot(kind="bar", title="ASIN Frequency")
plt.subplot(2,1,2)
sns.pointplot(x="asins", y="reviews.doRecommend", order=asins_count_ix,
              data=reviews)
plt.xticks(rotation=90)
plt.show()

# %%
corr_matrix = reviews.corr()
corr_matrix
# Out:
#                       reviews.didPurchase  reviews.id  reviews.numHelpful  \
# reviews.didPurchase                   NaN         NaN                 NaN
# reviews.id                            NaN         NaN                 NaN
# reviews.numHelpful                    NaN         NaN            1.000000
# reviews.rating                        NaN         NaN           -0.033887
# reviews.userCity                      NaN         NaN                 NaN
# reviews.userProvince                  NaN         NaN                 NaN
#
#                       reviews.rating  reviews.userCity  reviews.userProvince
# reviews.didPurchase              NaN               NaN                   NaN
# reviews.id                       NaN               NaN                   NaN
# reviews.numHelpful         -0.033887               NaN                   NaN
# reviews.rating              1.000000               NaN                   NaN
# reviews.userCity                 NaN               NaN                   NaN
# reviews.userProvince             NaN               NaN                   NaN

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12812 entries, 11057 to 13581
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    12790 non-null  object
#  1   name                  12790 non-null  object
#  2   asins                 12789 non-null  object
#  3   brand                 12790 non-null  object
#  4   categories            12790 non-null  object
#  5   keys                  12790 non-null  object
#  6   manufacturer          12790 non-null  object
#  7   reviews.date          12788 non-null  object
#  8   reviews.dateAdded     11512 non-null  object
#  9   reviews.dateSeen      12790 non-null  object
#  10  reviews.didPurchase   0 non-null      float64
#  11  reviews.doRecommend   12468 non-null  object
#  12  reviews.id            0 non-null      float64
#  13  reviews.numHelpful    12479 non-null  float64
#  14  reviews.rating        12790 non-null  float64
#  15  reviews.sourceURLs    12790 non-null  object
#  16  reviews.text          12789 non-null  object
#  17  reviews.title         12790 non-null  object
#  18  reviews.userCity      0 non-null      float64
#  19  reviews.userProvince  0 non-null      float64
#  20  reviews.username      12789 non-null  object
# dtypes: float64(6), object(15)
# memory usage: 2.7+ MB

# %%
counts = reviews["asins"].value_counts().to_frame()
counts.head()
# Out:
#             asins
# B018Y229OU   8817
# B01AHB9CN2   2265
# B018Y225IA    791
# B01J2G4VBG    312
# B018Y23MNM    184

# %%
avg_rating = reviews.groupby("asins")["reviews.rating"].mean().to_frame()
avg_rating.head()
# Out:
#             reviews.rating
# asins
# B005PB2T0S        4.000000
# B005PB2T2Q        3.333333
# B00DU15MU4        5.000000
# B00IOYAM4I        4.815789
# B00REQKWGA        4.600000

# %%
table = counts.join(avg_rating)
table.head(30)
# Out:
#             asins  reviews.rating
# B018Y229OU   8817        4.456958
# B01AHB9CN2   2265        4.598675
# B018Y225IA    791        4.508217
# B01J2G4VBG    312        4.423077
# B018Y23MNM    184        4.543478
# B00ZV9PXP2    166        4.554217
# B01AHB9CYG    130        4.538462
# B00VINDBJK     57        4.684211
# B00IOYAM4I     38        4.815789
# B01AHB9C1E     10        4.700000
# B018T075DC      5        5.000000
# B005PB2T0S      5        4.000000
# B00REQKWGA      5        4.600000
# B005PB2T2Q      3        3.333333
# B00DU15MU4      1        5.000000

# %%
plt.scatter("asins", "reviews.rating", data=table)
table.corr()
# Out:
#                    asins  reviews.rating
# asins           1.000000       -0.026825
# reviews.rating -0.026825        1.000000

# %%
data["Sentiment"] = data["reviews.rating"]
data["reviews.rating"].replace({5.0: "positive",4.0:"positive",3.0:"neutral",2.0:"negative",1.0:"negative"}, inplace=True)
data["reviews.rating"].unique()
# Out:
# array(['positive', 'negative', 'neutral', nan], dtype=object)

# %% [markdown]
# ## Most repeated words in reviews

# %% [markdown]
# ## Generating wordcloud based on category

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.21.5)

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator




stopwords = set(STOPWORDS)
def word_cloud(data, title):
    wordcloud = WordCloud(
    background_color = "black",
    max_font_size = 40,
    max_words = 200,
    stopwords = stopwords,
    scale = 3).generate(str(data))
    fig = plt.figure(figsize = (7.5, 7.5))
    plt.axis("off")
    if title: 
        fig.suptitle(title, fontsize=15)
        fig.subplots_adjust(top=2.25)
    plt.imshow(wordcloud)
    plt.show()
# seperating all records into a different variable to generate wordcloud based on category
neu=data[data["reviews.rating"] == "neutral"]["reviews.title"]
neg=data[data["reviews.rating"] == "negative"]["reviews.title"]
pos=data[data["reviews.rating"] == "positive"]["reviews.title"]

# %%
word_cloud(neu, "Most Repeated words in neutral reviews")
word_cloud(pos, "Most Repeated words in positive reviews")
word_cloud(neg, "Most Repeated words in negative reviews")

# %%
def sentiments(rating):
    if (rating == 5) or (rating == 4):
        return "Positive"
    elif rating == 3:
        return "Neutral"
    elif (rating == 2) or (rating == 1):
        return "Negative"
# Add sentiments to the data
strat_train["Sentiment"] = strat_train["reviews.rating"].apply(sentiments)
strat_test["Sentiment"] = strat_test["reviews.rating"].apply(sentiments)
strat_train["Sentiment"][:20]
# Out:
# 11057    Positive
# 5523     Positive
# 7131     Positive
# 8560     Negative
# 3281     Positive
# 6913     Positive
# 435      Positive
# 155      Positive
# 11500    Positive
# 3749     Positive
# 9096     Positive
# 13013     Neutral
# 15578    Negative
# 2838     Positive
# 4501     Negative
# 9203     Positive
# 7239     Positive
# 8944     Positive
# 1760     Positive
# 1654     Positive
# Name: Sentiment, dtype: object

# %% [markdown]
# ## Prepare data

# %%
X_train = strat_train["reviews.text"]
X_train_targetSentiment = strat_train["Sentiment"]
X_test = strat_test["reviews.text"]
X_test_targetSentiment = strat_test["Sentiment"]
print(len(X_train), len(X_test))
# Out:
# 12812 3204

# %% [markdown]
# ## Replace "nan" with space

# %%
X_train = X_train.fillna(' ')
X_test = X_test.fillna(' ')
X_train_targetSentiment = X_train_targetSentiment.fillna(' ')
X_test_targetSentiment = X_test_targetSentiment.fillna(' ')

# %% [markdown]
# ## Text preprocessing and occurance counting

# %%
from sklearn.feature_extraction.text import CountVectorizer 
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train) 
X_train_counts.shape
# Out:
# (12812, 7773)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer(use_idf=False)
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (12812, 7773)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
clf_multiNB_pipe = Pipeline([("vect", CountVectorizer()), 
                             ("tfidf", TfidfTransformer()),
                             ("clf_nominalNB", MultinomialNB())])
clf_multiNB_pipe.fit(X_train, X_train_targetSentiment)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf_nominalNB', MultinomialNB())])

# %% [markdown]
# ## Test Model

# %%
import numpy as np
predictedMultiNB = clf_multiNB_pipe.predict(X_test)
NB=np.mean(predictedMultiNB == X_test_targetSentiment)
NB
# Out:
# 0.9073033707865169

# %% [markdown]
# ## Testing Other Models

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
clf_logReg_pipe = Pipeline([("vect", CountVectorizer()), 
                            ("tfidf", TfidfTransformer()), 
                            ("clf_logReg", LogisticRegression())])
clf_logReg_pipe.fit(X_train, X_train_targetSentiment)

import numpy as np
predictedLogReg = clf_logReg_pipe.predict(X_test)
LR=np.mean(predictedLogReg == X_test_targetSentiment)
LR
# Out:
# 0.9122971285892634

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import LinearSVC
clf_linearSVC_pipe = Pipeline([("vect", CountVectorizer()), 
                               ("tfidf", TfidfTransformer()),
                               ("clf_linearSVC", LinearSVC())])
clf_linearSVC_pipe.fit(X_train, X_train_targetSentiment)

predictedLinearSVC = clf_linearSVC_pipe.predict(X_test)
LSVC=np.mean(predictedLinearSVC == X_test_targetSentiment)
LSVC
# Out:
# 0.9126092384519351

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf_decisionTree_pipe = Pipeline([("vect", CountVectorizer()), 
                                  ("tfidf", TfidfTransformer()), 
                                  ("clf_decisionTree", DecisionTreeClassifier())
                                 ])
clf_decisionTree_pipe.fit(X_train, X_train_targetSentiment)

predictedDecisionTree = clf_decisionTree_pipe.predict(X_test)
DT=np.mean(predictedDecisionTree == X_test_targetSentiment)
DT
# Out:
# 0.8723470661672909

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
clf_randomForest_pipe = Pipeline([("vect", CountVectorizer()), 
                                  ("tfidf", TfidfTransformer()), 
                                  ("clf_randomForest", RandomForestClassifier())
                                 ])
clf_randomForest_pipe.fit(X_train, X_train_targetSentiment)

predictedRandomForest = clf_randomForest_pipe.predict(X_test)
RF=np.mean(predictedRandomForest == X_test_targetSentiment)
RF
# Out:
# 0.9091760299625468

# %%
acu = [NB,LR,LSVC,DT,RF]
comp = pd.DataFrame({'Accuracy': acu})
label = ['MultinomialNB',' LogisticRegression','LinearSVC','DecisionTree','RandomForest']
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(12,5))
ax = comp['Accuracy'].plot(kind='bar',title="Algorithm Classification")
ax.set_xticklabels(label)
# Out:
# [Text(0, 0, 'MultinomialNB'),
#  Text(0, 0, ' LogisticRegression'),
#  Text(0, 0, 'LinearSVC'),
#  Text(0, 0, 'DecisionTree'),
#  Text(0, 0, 'RandomForest')]

# %% [markdown]
# ## Fine tuning the Support Vector Machine Classifier

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'vect__ngram_range': [(1, 1), (1, 2)],    
             'tfidf__use_idf': (True, False), 
             } 
gs_clf_LinearSVC_pipe = GridSearchCV(clf_linearSVC_pipe, parameters, n_jobs=-1)
gs_clf_LinearSVC_pipe = gs_clf_LinearSVC_pipe.fit(X_train, 
                                                  X_train_targetSentiment)
new_text = ["The tablet is good, really liked it.", 
            "The tablet is ok, but it works fine.", 
            "The tablet is not good, does not work very well."] # negative
print(new_text)
gs_clf_LinearSVC_pipe.predict(new_text)

# %%
predictedGS_clf_LinearSVC_pipe = gs_clf_LinearSVC_pipe.predict(X_test)
np.mean(predictedGS_clf_LinearSVC_pipe == X_test_targetSentiment)

# %% [markdown]
# ## Detailed Performance Analysis of Support Vector Machine Classifier

# %%
for performance_analysis in (gs_clf_LinearSVC_pipe.best_score_, 
                             gs_clf_LinearSVC_pipe.best_estimator_, 
                             gs_clf_LinearSVC_pipe.best_params_):
        print(performance_analysis)

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

print(classification_report(X_test_targetSentiment, 
                            predictedGS_clf_LinearSVC_pipe))
print('Accuracy: {}'. format(accuracy_score(X_test_targetSentiment, 
                             predictedGS_clf_LinearSVC_pipe)))

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn import metrics
metrics.confusion_matrix(X_test_targetSentiment,
                         predictedGS_clf_LinearSVC_pipe)

# %%
import pickle

# %%
with open('model_pickle','wb') as f:
    pickle.dump(gs_clf_LinearSVC_pipe,f)

# %%
with open('model_pickle','rb') as f:
    model = pickle.load(f)

# %%
print(model.predict(new_text))
